# %% [markdown]
# # Encoding based on the type categorical data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder,LabelEncoder

# %%
np.random.seed(42)
n = 50

df = pd.DataFrame({
    #Nominal
    'Gender':np.random.choice(['Male', 'Female', 'Others'], n),
    'Color' :np.random.choice(['Red', 'Green', 'Blue', 'Yellow'], n),

    #Ordinal
    'Education':np.random.choice(['HighSchool', 'Bachelors', 'Masters', 'Phd'], n),
    'Satisfaction':np.random.choice(['Low', 'Medium', 'high'], n),

    #Binary
    'HasCar':np.random.choice([0,1], n),

    #High Cardinality
    'City':np.random.choice([f'City_{i}' for i in range(1, 11)], n)
})

df.head()
# Out:
#    Gender  Color   Education Satisfaction  HasCar    City
# 0  Others  Green  HighSchool          Low       1  City_7
# 1    Male    Red   Bachelors         high       1  City_2
# 2  Others  Green     Masters       Medium       1  City_3
# 3  Others    Red  HighSchool         high       1  City_1
# 4    Male  Green         Phd         high       1  City_5

# %%
df['Education'].value_counts()
# Out:
# Education
# HighSchool    17
# Phd           14
# Masters       13
# Bachelors      6
# Name: count, dtype: int64
